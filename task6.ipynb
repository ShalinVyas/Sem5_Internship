# %% [markdown]
# # **Seaborn**

# %% [markdown]
#  Task 1: Create a new dataset offline from the Sales_channel column using the Sales dataset.
# Task 2: According to task 2 now plot bar graph of unit cost and No_product using offline.
# Task 3: Plot pie chart for item_type and No_product column using Sales dataset.
#
# Task 4: Plot pie chart for Region and Gross_margin column using Sales dataset.
#
# Task 5: According to Task 3,4 plot subplot of it.

# %% [markdown]
# Import Library

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# Load File

# %%
df=pd.read_csv("drive/MyDrive/sales.csv")

# %%
df
# Out:
#                                Region                Country        Item_Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub_Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub_Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub_Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub_Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub_Saharan Africa             Mozambique        Household
#
# ...

# %% [markdown]
# **Task 1**

# %%
offline= df[["Sales_Channel"]]

# %% [markdown]
# **Task 2**

# %% [markdown]
# Import Library

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
df["no_product"] =(df["Total_Revenue"] / df["Unit_Cost"])

# %%
x=df["no_product"]

# %%
y=df["Unit_Cost"]

# %%
plt.bar(y,x)
# Out:
# <BarContainer object of 100 artists>

# %% [markdown]
# **Task 3**

# %%
x=df["Item_Type"]

# %%
y=df["no_product"]

# %%
plt.pie(y,labels=x)
plt.title("Task 3")
# Out:
# Text(0.5, 1.0, 'Task 3')

# %% [markdown]
# **Task 4**

# %%
df["gross_margin"]=df["Total_Profit"]/df["no_product"]

# %%
df["gross_margin"]
# Out:
# 0      59.863684
# 1      50.436436
# 2     101.773929
# 3       1.787481
# 4     101.773929
#          ...
# 95     24.085739
# 96      1.787481
# 97     37.260878
# 98     17.376119
# 99    124.629198
# Name: gross_margin, Length: 100, dtype: float64

# %%
a=df["Region"]

# %%
b=df["gross_margin"]

# %%
plt.pie(b,labels=a)
plt.title("Task 4")
# Out:
# Text(0.5, 1.0, 'Task 4')

# %% [markdown]
# **Task 5**

# %%
fig,(a1,a2)=plt.subplots(ncols=2,figsize=(25,7))
a1.bar(y,x)
a1.set_title("Task 3")
a2.bar(b,a)
a2.set_title("Task 4")
plt.show()
